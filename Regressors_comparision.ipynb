# %% [markdown]
# <a href="https://colab.research.google.com/github/arienox/Bioactivity--Drug-Discovery/blob/main/Regressors_comparision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Libraries **

# %%
# !pip install lazypredict

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %% [markdown]
# # **Load the data set**

# %%
df = pd.read_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
x = df.drop('pIC50', axis=1)
y = df.pIC50

# %% [markdown]
# # **3. Data Pre-processsing**

# %%
#Examine X dimension
x.shape
# Out:
# (133, 882)

# %%
#Removing low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))
x = selection.fit_transform(x)
x.shape
# Out:
# (133, 201)

# %%
#Perform data splitting using 80/20 ratio
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# # **4. Compare ML algorithms**

# %%
#Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
train, test = clf.fit(x_train, x_test, y_train, y_test)
# Out:
# 100%|██████████| 42/42 [00:24<00:00,  1.72it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000585 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 637
# [LightGBM] [Info] Number of data points in the train set: 106, number of used features: 201
# [LightGBM] [Info] Start training from score 4.711492
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
#Performance table of the training set (80% subset)
train
# Out:
#                                                               Adjusted R-Squared  \
# Model
# Lars                          16832031492355095342004200372140465467022772089...
# TransformedTargetRegressor                           240698756740140358434816.00
# LinearRegression                                     240698756740140358434816.00
# KernelRidge                                                                 5.06
# GaussianProcessRegressor                                                    2.76
# LassoLars                                                                   1.15
# Lasso                                                                       1.15
# ElasticNet                                                                  1.15
# DummyRegressor                                                              1.15
# DecisionTreeRegressor                                                       1.14
# ...

# %%
#performance table of the test set (20% subset)
test
# Out:
#                                                               Adjusted R-Squared  \
# Model
# Lars                          16832031492355095342004200372140465467022772089...
# TransformedTargetRegressor                           240698756740140358434816.00
# LinearRegression                                     240698756740140358434816.00
# KernelRidge                                                                 5.06
# GaussianProcessRegressor                                                    2.76
# LassoLars                                                                   1.15
# Lasso                                                                       1.15
# ElasticNet                                                                  1.15
# DummyRegressor                                                              1.15
# DecisionTreeRegressor                                                       1.14
# ...

# %% [markdown]
# # **5. Data Visualization of model performance**

# %%
#Bar Plot of R-squared value
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i<0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(x="R-Squared", y= train.index, data=train)
ax.set(xlim=(0,1))
#
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=train.index, x="RMSE", data=train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=train.index, x="Time Taken", data=train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
